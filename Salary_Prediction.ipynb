# %% [markdown]
# # SALARY PREDICTION USING LINEAR REGRESSION ALGORITHM

# %% [markdown]
# ## PROBLEM STATEMENT :

# %% [markdown]
# ### From a Given Dataset which have gross and Annual Salaries of the Employees, Predict the salaries of the Employees.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

from sklearn.linear_model import LinearRegression

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Reading the csv dataset using pandas library

# %%
df = pd.read_csv('Dataset.csv')

# %%
df
# Out:
#                        Name                       JobTitle AgencyID  \
# 0           Aaron,Keontae E                 AIDE BLUE CHIP   W02200
# 1          Aaron,Patricia G  Facilities/Office Services II   A03031
# 2             Aaron,Petra L     ASSISTANT STATE'S ATTORNEY   A29005
# 3        Abaineh,Yohannes T                 EPIDEMIOLOGIST   A65026
# 4          Abbene,Anthony M         POLICE OFFICER TRAINEE   A99416
# ...                     ...                            ...      ...
# 18976  Zotamou,Jean Marie D                 AIDE BLUE CHIP   W02235
# 18977       Zotamou,Pivot D                 AIDE BLUE CHIP   W02629
# 18978  Zovistoski,Zachary D         POLICE OFFICER TRAINEE   A99416
# 18979     Zubyk,Stanislav T                 POLICE OFFICER   A99262
# 18980    Zukowski,Charles J   Waste Water Tech Supv I Pump   A50206
#
#                          Agency    HireDate AnnualSalary   GrossPay
# 0                Youth Summer    06/10/2013    $11310.00    $873.63
# 1           OED-Employment Dev   10/24/1979    $53428.00  $52868.38
# 2      States Attorneys Office   09/25/2006    $68300.00  $67439.19
# 3       HLTH-Health Department   07/23/2009    $62000.00  $58654.74
# 4            Police Department   07/24/2013    $43999.00  $39686.95
# ...                         ...         ...          ...        ...
# 18976            Youth Summer    05/21/2014    $11310.00        NaN
# 18977             Youth Summer   05/21/2014    $11310.00        NaN
# 18978        Police Department   12/17/2013    $43999.00  $21070.03
# 18979        Police Department   01/23/2013    $44104.00  $48608.12
# 18980  DPW-Water & Waste Water   10/15/1979    $53568.00  $52164.32
#
# [18981 rows x 7 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18981 entries, 0 to 18980
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0    Name         18981 non-null  object
#  1   JobTitle      18981 non-null  object
#  2   AgencyID      18981 non-null  object
#  3   Agency        18981 non-null  object
#  4   HireDate      18911 non-null  object
#  5   AnnualSalary  18981 non-null  object
#  6   GrossPay      15758 non-null  object
# dtypes: object(7)
# memory usage: 1.0+ MB

# %%
df.isnull().sum() # checking for null values
# Out:
#  Name              0
# JobTitle           0
# AgencyID           0
# Agency             0
# HireDate          70
# AnnualSalary       0
# GrossPay        3223
# dtype: int64

# %% [markdown]
# ## DATA PREPROCESSING

# %%
salary_pred_cpy = df.copy() # making a copy of the dataset.

# %%
salary_pred_cpy.columns # checking  for only necessary Columns.
# Out:
# Index([' Name', 'JobTitle', 'AgencyID', 'Agency', 'HireDate', 'AnnualSalary',
#        'GrossPay'],
#       dtype='object')

# %%
salary_pred_cpy=salary_pred_cpy.drop(' Name',axis=1) # Droping Name Column as it is of no use for prediction.

# %%
salary_pred_cpy = salary_pred_cpy.dropna(subset=['HireDate']) # Only Droping rows Which Have HireDate Value as NaN

# %%
salary_pred_cpy=salary_pred_cpy.drop('GrossPay',axis=1) #Droping GrossPay Column

# %%
salary_pred_cpy.isnull().sum()
# Out:
# JobTitle        0
# AgencyID        0
# Agency          0
# HireDate        0
# AnnualSalary    0
# dtype: int64

# %%
salary_pred_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18911 entries, 0 to 18980
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   JobTitle      18911 non-null  object
#  1   AgencyID      18911 non-null  object
#  2   Agency        18911 non-null  object
#  3   HireDate      18911 non-null  object
#  4   AnnualSalary  18911 non-null  object
# dtypes: object(5)
# memory usage: 886.5+ KB

# %%
salary_pred_cpy['AnnualSalary']=salary_pred_cpy['AnnualSalary'].apply(lambda x : float(str(x)[1:])) # Removing $ sign in the Annual Salary Columns

# %%
salary_pred_cpy['AnnualSalary']
# Out:
# 0        11310.0
# 1        53428.0
# 2        68300.0
# 3        62000.0
# 4        43999.0
#           ...
# 18976    11310.0
# 18977    11310.0
# 18978    43999.0
# 18979    44104.0
# 18980    53568.0
# Name: AnnualSalary, Length: 18911, dtype: float64

# %%
salary_pred_cpy['month']=salary_pred_cpy['HireDate'].apply(lambda x : int(str(x[0:2]))) # HireDate is divided into day month year 
salary_pred_cpy['day']=salary_pred_cpy['HireDate'].apply(lambda x : int(str(x[3:5])))
salary_pred_cpy['year']=salary_pred_cpy['HireDate'].apply(lambda x : int(str(x[6:])))
salary_pred_cpy
# Out:
#                             JobTitle AgencyID                    Agency  \
# 0                     AIDE BLUE CHIP   W02200            Youth Summer
# 1      Facilities/Office Services II   A03031       OED-Employment Dev
# 2         ASSISTANT STATE'S ATTORNEY   A29005  States Attorneys Office
# 3                     EPIDEMIOLOGIST   A65026   HLTH-Health Department
# 4             POLICE OFFICER TRAINEE   A99416        Police Department
# ...                              ...      ...                       ...
# 18976                 AIDE BLUE CHIP   W02235            Youth Summer
# 18977                 AIDE BLUE CHIP   W02629             Youth Summer
# 18978         POLICE OFFICER TRAINEE   A99416        Police Department
# 18979                 POLICE OFFICER   A99262        Police Department
# 18980   Waste Water Tech Supv I Pump   A50206  DPW-Water & Waste Water
#
#          HireDate  AnnualSalary  month  day  year
# 0      06/10/2013       11310.0      6   10  2013
# 1      10/24/1979       53428.0     10   24  1979
# 2      09/25/2006       68300.0      9   25  2006
# 3      07/23/2009       62000.0      7   23  2009
# 4      07/24/2013       43999.0      7   24  2013
# ...           ...           ...    ...  ...   ...
# 18976  05/21/2014       11310.0      5   21  2014
# 18977  05/21/2014       11310.0      5   21  2014
# 18978  12/17/2013       43999.0     12   17  2013
# 18979  01/23/2013       44104.0      1   23  2013
# 18980  10/15/1979       53568.0     10   15  1979
#
# [18911 rows x 8 columns]

# %%
salary_pred_cpy.JobTitle.value_counts()
# Out:
# AIDE BLUE CHIP                    4817
# POLICE OFFICER                    1866
# LABORER (Hourly)                   597
# EMT Firefighter Suppression        358
# CROSSING GUARD                     337
#                                   ...
# PUBLIC INFORMATION OFFICER SAO       1
# STREET MASON                         1
# DESIGN PLANNER I                     1
# FUEL SYSTEMS SPECIALIST              1
# Research Analyst II                  1
# Name: JobTitle, Length: 1073, dtype: int64

# %%
salary_pred_cpy.Agency.value_counts()
# Out:
# Youth Summer                4323
# Police Department           3141
# Fire Department             1576
# DPW-Water & Waste Water     1491
# HLTH-Health Department       833
#                             ...
# Council Services               6
# HLTH-Health Dept Locatio       6
# Legislative Reference          5
# M-R Cable & Comm               4
# Special City Services          4
# Name: Agency, Length: 65, dtype: int64

# %%
salary_pred_cpy.AgencyID.value_counts() #one agency is having multiple agency ids
# Out:
# P04001    316
# C90786    276
# W02629    193
# P04002    191
# A99416    166
#          ...
# W02525      1
# W02400      1
# A64005      1
# W02666      1
# W02339      1
# Name: AgencyID, Length: 1177, dtype: int64

# %%
salary_pred_cpy.AnnualSalary.value_counts()
# Out:
# 11310.0    4811
# 20800.0     325
# 29245.0     196
# 43999.0     169
# 44773.0     162
#            ...
# 58227.0       1
# 41704.0       1
# 44700.0       1
# 43000.0       1
# 900.0         1
# Name: AnnualSalary, Length: 1590, dtype: int64

# %%
salary_pred_cpy.HireDate.value_counts()
# Out:
# 05/21/2014    1478
# 06/10/2013     696
# 06/12/2012     541
# 06/07/2011     368
# 05/29/2014     347
#               ...
# 02/13/2009       1
# 08/12/1993       1
# 02/09/1998       1
# 05/06/1980       1
# 10/15/1979       1
# Name: HireDate, Length: 4737, dtype: int64

# %%
salary_pred_cpy.AnnualSalary.plot.box()
# Out:
# <AxesSubplot:>

# %%
salary_pred_cpy.AnnualSalary.describe()
# Out:
# count     18911.000000
# mean      39660.421889
# std       25163.465942
# min           0.000000
# 25%       11310.000000
# 50%       36203.000000
# 75%       60300.000000
# max      238772.000000
# Name: AnnualSalary, dtype: float64

# %%
salary_pred_cpy=salary_pred_cpy[salary_pred_cpy['AnnualSalary']<135000] # Removing the outliers
# An outlier is a data point that is noticeably different from the rest.

# %%
salary_pred_cpy.AnnualSalary.plot.box()
# Out:
# <AxesSubplot:>

# %%
salary_pred_cpy.AnnualSalary.describe()
# Out:
# count     18872.000000
# mean      39426.790713
# std       24637.332423
# min           0.000000
# 25%       11310.000000
# 50%       36203.000000
# 75%       60200.000000
# max      132600.000000
# Name: AnnualSalary, dtype: float64

# %% [markdown]
# ## DISCOVERING THE PATTERNS AND ANALYSING THE DATASET

# %%
#CHECK THE DISTRIBUTION OF ANNUAL SALARY

sns.distplot(salary_pred_cpy.AnnualSalary,color='Black')
plt.title('Annual Salary Distribution')
plt.figure(figsize=(50,50))

# %%
plt.figure(figsize=(50,50))
sns.jointplot(x='JobTitle',y='AnnualSalary',data = salary_pred_cpy,color='Black')
plt.xticks(rotation = 90,color='Black')
# Out:
# (array([    0.,  5000., 10000.]), [])

# %%
 # Top 5 Jobs Which Are Likely To Be Hired 
    
plt.figure(figsize=(10,5))
salary_pred_cpy.groupby(['JobTitle'])['JobTitle'].count().sort_values(ascending = False ).head(5).plot.bar(color='Black')
plt.ylabel('No of Employees')
plt.title('Top 5 Jobs')
# Out:
# Text(0.5, 1.0, 'Top 5 Jobs')

# %%
# Top 5 Highest Paying Jobs 

plt.figure(figsize=(10,5))
salary_pred_cpy.groupby(['JobTitle'])['AnnualSalary'].mean().sort_values(ascending=False).head(5).plot.bar(color='Black')
plt.title('Top 5 Paying Jobs')
# Out:
# Text(0.5, 1.0, 'Top 5 Paying Jobs')

# %%
#Average Salary Offered 

mean_salary = salary_pred_cpy.AnnualSalary.mean()
mean_salary
# Out:
# 39426.79071322594

# %%
#How Many Jobs Are There with salary greater than avg salary

x=salary_pred_cpy.groupby(['JobTitle'])['AnnualSalary'].mean().reset_index()
x
# Out:
#                          JobTitle  AnnualSalary
# 0               911 LEAD OPERATOR  47886.000000
# 1                    911 OPERATOR  42835.743590
# 2         911 OPERATOR SUPERVISOR  54797.500000
# 3               ACCOUNT EXECUTIVE  42960.000000
# 4                    ACCOUNTANT I  46316.642857
# ...                           ...           ...
# 1062         ZONING ADMINISTRATOR  82100.000000
# 1063  ZONING APPEALS ADVISOR BMZA  59274.000000
# 1064   ZONING ENFORCEMENT OFFICER  62000.000000
# 1065            ZONING EXAMINER I  43674.000000
# 1066           ZONING EXAMINER II  53568.000000
#
# [1067 rows x 2 columns]

# %%
x[x['AnnualSalary']>mean_salary]['JobTitle'].count()
# Out:
# 808

# %%
#Top 5 Agencies that have hired Higher No of Employees 

plt.figure(figsize=(10,5))
salary_pred_cpy.groupby(['Agency'])['HireDate'].count().sort_values(ascending=False).head(5).plot.bar(color='Black')
plt.ylabel('No of Employees')
plt.title('Top 5 Agencies')
# Out:
# Text(0.5, 1.0, 'Top 5 Agencies')

# %%
# Which AgencyId Have Higher No Of PPl working For 

plt.figure(figsize=(10,5))
salary_pred_cpy.groupby(['AgencyID'])['HireDate'].count().sort_values(ascending=False).head(5).plot.bar(color='Black')
plt.ylabel('No of Employees')
plt.title('Top 5 AgencyIDs With Highest No of Employees')
# Out:
# Text(0.5, 1.0, 'Top 5 AgencyIDs With Highest No of Employees')

# %%
# Relation b/w Year and Salary 

salary_pred_cpy.head()
# Out:
#                         JobTitle AgencyID                    Agency  \
# 0                 AIDE BLUE CHIP   W02200            Youth Summer
# 1  Facilities/Office Services II   A03031       OED-Employment Dev
# 2     ASSISTANT STATE'S ATTORNEY   A29005  States Attorneys Office
# 3                 EPIDEMIOLOGIST   A65026   HLTH-Health Department
# 4         POLICE OFFICER TRAINEE   A99416        Police Department
#
#      HireDate  AnnualSalary  month  day  year
# 0  06/10/2013       11310.0      6   10  2013
# 1  10/24/1979       53428.0     10   24  1979
# 2  09/25/2006       68300.0      9   25  2006
# 3  07/23/2009       62000.0      7   23  2009
# 4  07/24/2013       43999.0      7   24  2013

# %%
sns.lineplot(salary_pred_cpy['year'],salary_pred_cpy['AnnualSalary'],color='black')
# Out:
# <AxesSubplot:xlabel='year', ylabel='AnnualSalary'>

# %%
salary_pred_cpy.groupby(['year'])['AnnualSalary'].mean().sort_values().head(10).plot.bar(color='Black')
# Out:
# <AxesSubplot:xlabel='year'>

# %%
# Impact Of Month On Salary

salary_pred_cpy.groupby(['month'])['AnnualSalary'].mean().sort_values().head(10).plot.bar(color='Black')
# Out:
# <AxesSubplot:xlabel='month'>

# %%
#Highest No Of PPl Hired on Which Month 

salary_pred_cpy.groupby(['month'])['AnnualSalary'].count().sort_values(ascending=False).head(10).plot.bar(color='Black')
#From plot majority freshers are hired on the month 6th or 5th
# Out:
# <AxesSubplot:xlabel='month'>

# %% [markdown]
# ## MultiVariate Analysis

# %%
sns.pairplot(salary_pred_cpy)
# A pairs plot allows us to see both distribution of single variables and relationships between two variables

# %%
sns.heatmap(salary_pred_cpy.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
#Feature Engineering 

Mean_Job = salary_pred_cpy.groupby(['JobTitle'])['AnnualSalary'].mean()
Mean_Job
# Out:
# JobTitle
# 911 LEAD OPERATOR              47886.000000
# 911 OPERATOR                   42835.743590
# 911 OPERATOR SUPERVISOR        54797.500000
# ACCOUNT EXECUTIVE              42960.000000
# ACCOUNTANT I                   46316.642857
#                                    ...
# ZONING ADMINISTRATOR           82100.000000
# ZONING APPEALS ADVISOR BMZA    59274.000000
# ZONING ENFORCEMENT OFFICER     62000.000000
# ZONING EXAMINER I              43674.000000
# ZONING EXAMINER II             53568.000000
# Name: AnnualSalary, Length: 1067, dtype: float64

# %%
salary_pred_cpy['JobTitle']=salary_pred_cpy['JobTitle'].map(Mean_Job)
salary_pred_cpy.head()
# Mapoing Titles with The mean Salary For that title
# Out:
#        JobTitle AgencyID                    Agency    HireDate  AnnualSalary  \
# 0  11313.967200   W02200            Youth Summer    06/10/2013       11310.0
# 1  47443.500000   A03031       OED-Employment Dev   10/24/1979       53428.0
# 2  69750.666667   A29005  States Attorneys Office   09/25/2006       68300.0
# 3  57940.000000   A65026   HLTH-Health Department   07/23/2009       62000.0
# 4  44531.160494   A99416        Police Department   07/24/2013       43999.0
#
#    month  day  year
# 0      6   10  2013
# 1     10   24  1979
# 2      9   25  2006
# 3      7   23  2009
# 4      7   24  2013

# %%
Mean_Agency = salary_pred_cpy.groupby(['Agency'])['AnnualSalary'].mean()
Mean_Agency
# Out:
# Agency
# COMP-Audits               65004.615385
# COMP-Communication Ser    37876.966667
# COMP-Comptroller's O      61513.772727
# COMP-Real Estate          64279.875000
# Circuit Court             56210.485214
#                               ...
# TRANS-Towing              33920.215385
# TRANS-Traffic             34172.489691
# Youth Summer              11346.315789
# Youth Summer              11310.270645
# Youth Temp Adult          24202.971014
# Name: AnnualSalary, Length: 65, dtype: float64

# %%
salary_pred_cpy['Agency']=salary_pred_cpy['Agency'].map(Mean_Agency)
salary_pred_cpy.head()
# Out:
#        JobTitle AgencyID        Agency    HireDate  AnnualSalary  month  day  \
# 0  11313.967200   W02200  11310.270645  06/10/2013       11310.0      6   10
# 1  47443.500000   A03031  50986.250000  10/24/1979       53428.0     10   24
# 2  69750.666667   A29005  64874.560224  09/25/2006       68300.0      9   25
# 3  57940.000000   A65026  39746.221420  07/23/2009       62000.0      7   23
# 4  44531.160494   A99416  61456.643609  07/24/2013       43999.0      7   24
#
#    year
# 0  2013
# 1  1979
# 2  2006
# 3  2009
# 4  2013

# %%
Mean_AgencyID = salary_pred_cpy.groupby(['AgencyID'])['AnnualSalary'].mean()
Mean_AgencyID
# Out:
# AgencyID
# A01001    58253.577662
# A01020    80547.000000
# A01030    70712.125000
# A02001    66376.466667
# A02002    42858.372549
#               ...
# W02698    11310.000000
# W02699    11310.000000
# W07900    24515.227273
# W07901    21840.000000
# W07905    15080.000000
# Name: AnnualSalary, Length: 1176, dtype: float64

# %%
salary_pred_cpy['AgencyID']=salary_pred_cpy['AgencyID'].map(Mean_AgencyID)
salary_pred_cpy.head()
# Out:
#        JobTitle      AgencyID        Agency    HireDate  AnnualSalary  month  \
# 0  11313.967200  11310.000000  11310.270645  06/10/2013       11310.0      6
# 1  47443.500000  46667.000000  50986.250000  10/24/1979       53428.0     10
# 2  69750.666667  65926.133333  64874.560224  09/25/2006       68300.0      9
# 3  57940.000000  48071.851064  39746.221420  07/23/2009       62000.0      7
# 4  44531.160494  44012.307229  61456.643609  07/24/2013       43999.0      7
#
#    day  year
# 0   10  2013
# 1   24  1979
# 2   25  2006
# 3   23  2009
# 4   24  2013

# %%
salary_pred_cpy.drop('HireDate',axis=1,inplace=True)
salary_pred_cpy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18872 entries, 0 to 18980
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   JobTitle      18872 non-null  float64
#  1   AgencyID      18872 non-null  float64
#  2   Agency        18872 non-null  float64
#  3   AnnualSalary  18872 non-null  float64
#  4   month         18872 non-null  int64
#  5   day           18872 non-null  int64
#  6   year          18872 non-null  int64
# dtypes: float64(4), int64(3)
# memory usage: 1.7 MB

# %% [markdown]
# ## TRAINING THE DATA USING ML ALGORTIHM

# %%
#train 80%
#test 20%
#random state gives us to train 80% of data from all over the data (100%)
#frst 0 next 40 next 80 next 120 and so on , end , until 80% is trained 

train,test = train_test_split(salary_pred_cpy,test_size=0.20,random_state = 40)

# %%
y_train=train.pop('AnnualSalary')
x_train=train
y_train
# Out:
# 6273     43999.0
# 14607    44773.0
# 16083    78998.0
# 4448     30430.0
# 10389    50698.0
#           ...
# 11620    63570.0
# 16167    11310.0
# 14598    49900.0
# 14652    11310.0
# 11678    32259.0
# Name: AnnualSalary, Length: 15097, dtype: float64

# %%
y_test=test.pop('AnnualSalary')
x_test=test
y_test
# Out:
# 10519    20800.0
# 1997     73013.0
# 14226    75288.0
# 584      11310.0
# 15603    11310.0
#           ...
# 10788    11310.0
# 11834    68460.0
# 18493    78897.0
# 16963    25644.0
# 557      41202.0
# Name: AnnualSalary, Length: 3775, dtype: float64

# %% [markdown]
# ## FEATURE SCALING

# %% [markdown]
# Feature scaling helps us to scale the data that all values or columns have equal weightage.

# %%
scaler = StandardScaler()
x_train[x_train.columns]=scaler.fit_transform(x_train[x_train.columns])

# %%
x_train
# Out:
#        JobTitle  AgencyID    Agency     month       day      year
# 6273   0.879027  0.829821  1.053299  1.564371  1.696635  0.664867
# 14607  0.879027  0.846619  1.053299  1.564371  0.264333  0.664867
# 16083  0.569191  0.005204  0.033519  1.564371 -1.764762  0.664867
# 4448   0.569191 -0.066967 -0.072298 -1.142601 -1.167969  0.954837
# 10389  1.242333  1.241247  1.501177 -1.819344  0.264333  0.761523
# ...         ...       ...       ...       ...       ...       ...
# 11620  0.879027  1.041754  1.053299 -0.127486 -1.167969  0.278241
# 16167 -1.161306 -1.266876 -1.340483 -0.465858  0.622408  0.954837
# 14598  0.597466  0.748181  0.360212 -0.465858  0.861125  0.664867
# 14652 -1.161306 -1.266876 -1.340483 -0.465858  0.622408  0.954837
# 11678 -0.319071  0.165164  0.293185 -0.465858 -1.526045 -0.011729
#
# [15097 rows x 6 columns]

# %%
scaler = StandardScaler()
x_test[x_test.columns]=scaler.fit_transform(x_test[x_test.columns])

# %%
x_test
# Out:
#        JobTitle  AgencyID    Agency     month       day      year
# 10519 -0.752717 -0.804208 -0.881625 -0.117837  0.987847  0.195735
# 1997   1.232015  1.273667  1.503949 -1.145961  1.820586 -0.655749
# 14226  1.591574  1.308867  1.052713 -0.803253  0.511996 -0.371921
# 584   -1.178656 -1.291477 -1.359016 -0.117837 -1.510369  0.574172
# 15603 -1.178656 -1.291477 -1.359016 -0.117837 -0.439705  0.763391
# ...         ...       ...       ...       ...       ...       ...
# 10788 -1.178656 -1.291477 -1.359016 -0.460545  1.582661  0.952609
# 11834  1.165518  1.397613  1.503949 -1.145961 -0.915556  0.006516
# 18493  1.586142  1.326026  1.052713  0.567579 -0.320742 -0.182703
# 16963 -0.584263 -0.450902  0.008576  0.224871 -1.748294  0.195735
# 557   -0.031033  0.150574  0.008576 -0.117837  1.582661  0.195735
#
# [3775 rows x 6 columns]

# %%
lr =LinearRegression()

# %%
salary_train = lr.fit(x_train,y_train)

# %%
y_pred=salary_train.predict(x_test)
y_pred
# Out:
# array([21558.88647725, 68894.51047911, 77198.37399578, ...,
#        76617.50009472, 24760.56479962, 38558.73504647])

# %%
y_test
# Out:
# 10519    20800.0
# 1997     73013.0
# 14226    75288.0
# 584      11310.0
# 15603    11310.0
#           ...
# 10788    11310.0
# 11834    68460.0
# 18493    78897.0
# 16963    25644.0
# 557      41202.0
# Name: AnnualSalary, Length: 3775, dtype: float64

# %% [markdown]
# ## PERCENTAGE ACCURACY IN PREDICTION

# %%
from sklearn.metrics import r2_score

# %%
Percentage_accuracy=r2_score(y_test,y_pred)
Percentage_accuracy=Percentage_accuracy*100
Percentage_accuracy
# Out:
# 96.79646059615693

# %% [markdown]
# ## PERCENTAGE ERROR IN PREDICTION

# %%
Percentage_error=r2_score(y_test,y_pred)
Percentage_error=100-Percentage_error*100
Percentage_error
# Out:
# 3.2035394038430667

# %% [markdown]
# ## CONCLUSION

# %% [markdown]
# DISCOVERED PATTERNS FROM THE DATASET AND MADE PREDICTIONS BASED ON THESE DATA.
